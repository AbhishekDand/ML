# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np
import pandas as pd

# %%
wine_df=pd.read_csv("C:/Users/ss727/Desktop/winequality-white.csv", header=0 ,delimiter=";")

# %%
wine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
print(wine_df['fixed acidity'])
# Out:
# 0       7.0
# 1       6.3
# 2       8.1
# 3       7.2
# 4       7.2
# 5       8.1
# 6       6.2
# 7       7.0
# 8       6.3
# 9       8.1
# 10      8.1
# 11      8.6
# 12      7.9
# 13      6.6
# 14      8.3
# 15      6.6
# 16      6.3
# 17      6.2
# 18      7.4
# 19      6.5
# 20      6.2
# 21      6.4
# 22      6.8
# 23      7.6
# 24      6.6
# 25      7.0
# 26      6.9
# 27      7.0
# 28      7.4
# 29      7.2
#        ...
# 4868    5.8
# 4869    6.6
# 4870    6.1
# 4871    5.0
# 4872    6.0
# 4873    5.7
# 4874    5.6
# 4875    7.4
# 4876    6.2
# 4877    5.9
# 4878    6.2
# 4879    6.6
# 4880    6.6
# 4881    5.0
# 4882    5.5
# 4883    4.9
# 4884    6.5
# 4885    6.6
# 4886    6.2
# 4887    6.2
# 4888    6.8
# 4889    4.9
# 4890    6.1
# 4891    5.7
# 4892    6.5
# 4893    6.2
# 4894    6.6
# 4895    6.5
# 4896    5.5
# 4897    6.0
# Name: fixed acidity, Length: 4898, dtype: float64

# %%
print(wine_df['volatile acidity'])
# Out:
# 0       0.270
# 1       0.300
# 2       0.280
# 3       0.230
# 4       0.230
# 5       0.280
# 6       0.320
# 7       0.270
# 8       0.300
# 9       0.220
# 10      0.270
# 11      0.230
# 12      0.180
# 13      0.160
# 14      0.420
# 15      0.170
# 16      0.480
# 17      0.660
# 18      0.340
# 19      0.310
# 20      0.660
# 21      0.310
# 22      0.260
# 23      0.670
# 24      0.270
# 25      0.250
# 26      0.240
# 27      0.280
# 28      0.270
# 29      0.320
#         ...
# 4868    0.230
# 4869    0.240
# 4870    0.320
# 4871    0.200
# 4872    0.420
# 4873    0.210
# 4874    0.200
# 4875    0.220
# 4876    0.380
# 4877    0.540
# 4878    0.530
# 4879    0.340
# 4880    0.340
# 4881    0.235
# 4882    0.320
# 4883    0.470
# 4884    0.330
# 4885    0.340
# 4886    0.210
# 4887    0.410
# 4888    0.220
# 4889    0.235
# 4890    0.340
# 4891    0.210
# 4892    0.230
# 4893    0.210
# 4894    0.320
# 4895    0.240
# 4896    0.290
# 4897    0.210
# Name: volatile acidity, Length: 4898, dtype: float64

# %%
import seaborn as sns

# %%
sns.pairplot(wine_df,diag_kind='kde')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
x=wine_df.drop('quality',axis=1)

# %%
y=wine_df[['quality']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
regression_model=LinearRegression()
regression_model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
wine_df.describe().transpose()
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free sulfur dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total sulfur dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# pH                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# quality               4898.0    5.877909   0.885639  3.00000    5.000000
#
#                             50%       75%        max
# fixed acidity           6.80000    7.3000   14.20000
# volatile acidity        0.26000    0.3200    1.10000
# citric acid             0.32000    0.3900    1.66000
# residual sugar          5.20000    9.9000   65.80000
# chlorides               0.04300    0.0500    0.34600
# free sulfur dioxide    34.00000   46.0000  289.00000
# total sulfur dioxide  134.00000  167.0000  440.00000
# density                 0.99374    0.9961    1.03898
# pH                      3.18000    3.2800    3.82000
# sulphates               0.47000    0.5500    1.08000
# alcohol                10.40000   11.4000   14.20000
# quality                 6.00000    6.0000    9.00000

# %%
for idx,col_name in enumerate(x_train.columns):
    print("The coefficient for {} is {}".format(col_name,regression_model.coef_[0][idx]))
# Out:
# The coefficient for fixed acidity is 0.05181836725158526
# The coefficient for volatile acidity is -1.9737563863927665
# The coefficient for citric acid is 0.006463265800531706
# The coefficient for residual sugar is 0.07663239115716322
# The coefficient for chlorides is -0.68033770393929
# The coefficient for free sulfur dioxide is 0.00315151230660643
# The coefficient for total sulfur dioxide is -0.00010542201520080674
# The coefficient for density is -136.14928966235232
# The coefficient for pH is 0.649299773525471
# The coefficient for sulphates is 0.5459298337331236
# The coefficient for alcohol is 0.20731974095457834

# %%
intercept=regression_model.intercept_
print("The intercept is {}".format(intercept))
# Out:
# The intercept is [136.33319298]

# %%
regression_model.score(x_test,y_test)
# Out:
# 0.2876435954262104

# %%
x.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# dtype: object

# %%
x.iloc[36]
# Out:
# fixed acidity             6.5000
# volatile acidity          0.3900
# citric acid               0.2300
# residual sugar            5.4000
# chlorides                 0.0510
# free sulfur dioxide      25.0000
# total sulfur dioxide    149.0000
# density                   0.9934
# pH                        3.2400
# sulphates                 0.3500
# alcohol                  10.0000
# Name: 36, dtype: float64

# %%
y_pred=regression_model.predict(x_test)

# %%
print(y_pred, y_test)
# Out:
# [[5.22248471]
#  [5.55578878]
#  [6.11649447]
#  ...
#  [5.86891353]
#  [6.02592345]
#  [5.75589867]]       quality
# 2414        4
# 1584        6
# 3248        7
# 645         5
# 3163        7
# 4895        6
# 600         6
# 1379        6
# 1554        7
# 643         5
# 1548        6
# 1624        7
# 4538        6
# 941         6
# 4447        6
# 2017        5
# 3495        7
# 4089        6
# 2126        5
# 3338        6
# 1884        5
# 1791        5
# 4871        6
# 1683        7
# 1988        6
# 200         5
# 2372        4
# 608         5
# 3371        6
# 791         7
# ...       ...
# 1498        6
# 548         7
# 2421        5
# 4096        5
# 1435        5
# 2234        5
# 1794        5
# 3318        7
# 4661        5
# 3492        7
# 4759        6
# 1403        8
# 464         5
# 4079        6
# 2739        7
# 2429        6
# 2569        6
# 940         5
# 3159        6
# 231         6
# 2472        6
# 2721        5
# 3408        6
# 2963        7
# 1143        5
# 1035        6
# 1381        7
# 2054        5
# 2296        7
# 3583        6
#
# [1225 rows x 1 columns]
